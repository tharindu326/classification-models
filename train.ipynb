# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 665 bytes | 665.00 KiB/s, done.
# From https://github.com/tharindu326/classification-models
#    4b90440..62f2550  main       -> origin/main
# Updating 4b90440..62f2550
# Fast-forward
#  evaluate.py  |  2 +-
#  inference.py |  4 ++--
#  train.py     | 19 ++++++++++---------
#  3 files changed, 13 insertions(+), 12 deletions(-)

# %%
# !rm -r TLDataset/ALL/PKG-C-NMC2019/train/.ipynb_checkpoints
# !rm -r TLDataset/ALL/PKG-C-NMC2019/train/.DS_STORE
# Out:
# rm: cannot remove ‘TLDataset/ALL/PKG-C-NMC2019/train/.ipynb_checkpoints’: No such file or directory
# rm: cannot remove ‘TLDataset/ALL/PKG-C-NMC2019/train/.DS_STORE’: No such file or directory

# %% [markdown]
# # Training

# %%
# start training
# !python train.py --model_name resnet50 --data_dir TLDataset/ALL/PKG-C-NMC2019 --num_classes 2 --num_epochs 50 --batch_size 64 --learning_rate 0.001 --momentum 0.9 --checkpoint_path model_checkpoints/ALL
# Out:
# Using device: cuda:0
# Training Data: 9383 samples
# Validation Data: 1278 samples
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch [1/50], Average Train Loss: 0.5040
# Validation Loss after Epoch 1: 0.4453
# Saved Best Model at epoch 1 with F1 score: 0.7465
# Epoch [2/50], Average Train Loss: 0.4332
# Validation Loss after Epoch 2: 0.4160
# ...

# %% [markdown]
# # Evaluation
#
# Here we evaluate the model trained.
#
# For eveluation make sure the class folders are there like the trin and val. This means for the evaluation, we need the labeling to evelautae the results.

# %%
# !python evaluate.py --model_name resnet50 --data_dir TLDataset/ALL/PKG-C-NMC2019/C-NMC_test_prelim_phase_data --model_path model_checkpoints/ALL/resnet50_best_epoch_46.pth --num_classes 2 --batch_size 32

# %% [markdown]
# # Inference

# %%
# !python inference.py --model_name resnet50 --image_path TLDataset/ALL/PKG-C-NMC2019/C-NMC_test_prelim_phase_data --model_path model_checkpoints/ALL/resnet50_best_epoch_46.pth --num_classes 2 --image_save results_C-NMC_test_prelim_phase_data
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# 225.bmp: Predicted class: CANCER (0), Confidence: 0.74
# 1104.bmp: Predicted class: NO_CANCER (1), Confidence: 0.76
# 807.bmp: Predicted class: NO_CANCER (1), Confidence: 0.66
# 1579.bmp: Predicted class: CANCER (0), Confidence: 0.87
# 1524.bmp: Predicted class: CANCER (0), Confidence: 0.99
# 1646.bmp: Predicted class: CANCER (0), Confidence: 0.92
# 1340.bmp: Predicted class: CANCER (0), Confidence: 0.91
# ...

# %%
# !python inference.py --model_name resnet50 --image_path TLDataset/ALL/PKG-C-NMC2019/C-NMC_test_final_phase_data --model_path model_checkpoints/ALL/resnet50_best_epoch_46.pth --num_classes 2 --image_save results_C-NMC_test_final_phase_data
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# 225.bmp: Predicted class: CANCER (0), Confidence: 0.84
# 2234.bmp: Predicted class: CANCER (0), Confidence: 0.88
# 1104.bmp: Predicted class: NO_CANCER (1), Confidence: 0.75
# 807.bmp: Predicted class: NO_CANCER (1), Confidence: 0.97
# 2018.bmp: Predicted class: CANCER (0), Confidence: 0.84
# 2193.bmp: Predicted class: CANCER (0), Confidence: 0.68
# 1579.bmp: Predicted class: CANCER (0), Confidence: 0.77
# ...

# %% [markdown]
# # Transfer learning
#
# Here we will use the trained model on ALL dataset to fintune it for AML dataset.
# We will retarin the AML dataset with the same pipeline but this time we will load the ALL model weights as pretrained model.

# %%
# !python train.py --model_name resnet50 --data_dir TLDataset/AML/PKG-AML-Cytomorphology_LMU --num_classes 2 --num_epochs 50 --batch_size 64 --learning_rate 0.001 --momentum 0.9 --checkpoint_path model_checkpoints/AML --pretrained_path model_checkpoints/ALL/resnet50_best_epoch_46.pth
# Out:
# Using device: cuda:0
# Training Data: 2764 samples
# Validation Data: 1184 samples
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch [1/50], Average Train Loss: 0.1633
# Validation Loss after Epoch 1: 0.0390
# ...

# %% [markdown]
# # Notes
#
# Evaluation and Inference can be done as same as mentioned in above commands for the new model. Only have to chnage the model path and the source images paths.
